# %% [markdown]
# # CS381/780: HW 0

# %% [markdown]
# # due on 9/16/2020

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Challenge 1: Add a html link to your LinkedIn Profile

# %% [markdown]
# <a href="https://www.linkedin.com/in/alexsalazarny/">Alex_Salazar - Linkedin</a>

# %% [markdown]
# ### Challenge 2: Include your LinkedIn Profile Picture here

# %% [markdown]
# ![AlexSalazar.jpg](attachment:AlexSalazar.jpg)
